# %%
import numpy as np

def sigmoid(x):
  """Sigmoid activation function"""
  return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
  """Derivative of the sigmoid activation function"""
  return x * (1 - x)

class NeuralNetwork:
  def __init__(self):
    """
    Initialize the neural network with specific weights and biases based on the provided information.
    """
    self.weights_ih = np.array([[0.15, 0.20], [0.25, 0.30]])  # Input to hidden weights
    self.weights_ho = np.array([[0.40, 0.50], [0.45, 0.55]])  # Hidden to output weights
    self.biases_h = np.array([0.35, 0.35])  # Hidden layer biases
    self.biases_o = np.array([0.60, 0.60])  # Output layer biases

  def feedforward(self, X):
    """
    Perform a forward pass through the network.
    """
    hidden_inputs = np.dot(X, self.weights_ih) + self.biases_h  # Calculate weighted sums for hidden layer
    hidden_outputs = sigmoid(hidden_inputs)  # Apply activation function

    output_inputs = np.dot(hidden_outputs, self.weights_ho) + self.biases_o  # Calculate weighted sums for output layer
    output_outputs = sigmoid(output_inputs)  # Apply activation function
    return hidden_outputs, output_outputs

  def backpropagate(self, X, y, learning_rate):
    """
    Perform a backward pass through the network and update weights.
    """
    # Forward pass (already implemented in feedforward)
    hidden_outputs, output_outputs = self.feedforward(X)

    # Calculate errors
    errors_output = y - output_outputs
    errors_hidden = np.dot(errors_output, self.weights_ho.T) * sigmoid_derivative(hidden_outputs)

    # Update weights
    self.weights_ho += np.dot(hidden_outputs.T, errors_output) * learning_rate
    self.weights_ih += np.dot(X.T, errors_hidden) * learning_rate

  def train(self, X, y, epochs, learning_rate):
    """
    Train the neural network for a specified number of epochs.
    """
    for epoch in range(epochs):
      for i in range(len(X)):
        self.backpropagate(X[i], y[i], learning_rate)

      print(f"Epoch {epoch+1} - Updated Weights:")
      print(f"  Input to Hidden: {self.weights_ih}")
      print(f"  Hidden to Output: {self.weights_ho}")
      print("\n")

# Define input and expected output (as provided)
inputs = np.array([[0.05, 0.10]])
expected_outputs = np.array([[0.01, 0.99]])

# Create neural network object
nn = NeuralNetwork()

# Train the network
nn.train(inputs, expected_outputs, 1000, 0.1)  # Train for 1000 epochs with learning rate 0.1

# Use the trained network for prediction
hidden_outputs, output_outputs = nn.feedforward(inputs)
print("Predicted output:", output_outputs)
# Out:
# Epoch 1 - Updated Weights:
#   Input to Hidden: [[0.14925752 0.19925752]
#  [0.24925752 0.29925752]]
#   Hidden to Output: [[0.36886603 0.46886603]
#  [0.41886603 0.51886603]]
#
#
# Epoch 2 - Updated Weights:
#   Input to Hidden: [[0.1485961 0.1985961]
#  [0.2485961 0.2985961]]
#   Hidden to Output: [[0.33854131 0.43854131]
#  [0.38854131 0.48854131]]
#
#
# Epoch 3 - Updated Weights:
#   Input to Hidden: [[0.14801108 0.19801108]
#  [0.24801108 0.29801108]]
#   Hidden to Output: [[0.30901935 0.40901935]
#  [0.35901935 0.45901935]]
#
#
# Epoch 4 - Updated Weights:
#   Input to Hidden: [[0.14749793 0.19749793]
#  [0.24749793 0.29749793]]
#   Hidden to Output: [[0.28029256 0.38029256]
#  [0.33029256 0.43029256]]
#
#
# Epoch 5 - Updated Weights:
#   Input to Hidden: [[0.14705229 0.19705229]
#  [0.24705229 0.29705229]]
#   Hidden to Output: [[0.25235236 0.35235236]
#  [0.30235236 0.40235236]]
#
#
# Epoch 6 - Updated Weights:
#   Input to Hidden: [[0.14666991 0.19666991]
#  [0.24666991 0.29666991]]
#   Hidden to Output: [[0.22518923 0.32518923]
#  [0.27518923 0.37518923]]
#
#
# Epoch 7 - Updated Weights:
#   Input to Hidden: [[0.14634674 0.19634674]
#  [0.24634674 0.29634674]]
#   Hidden to Output: [[0.19879277 0.29879277]
#  [0.24879277 0.34879277]]
#
#
# Epoch 8 - Updated Weights:
#   Input to Hidden: [[0.14607886 0.19607886]
#  [0.24607886 0.29607886]]
#   Hidden to Output: [[0.1731518 0.2731518]
#  [0.2231518 0.3231518]]
#
#
# Epoch 9 - Updated Weights:
#   Input to Hidden: [[0.14586254 0.19586254]
#  [0.24586254 0.29586254]]
#   Hidden to Output: [[0.14825443 0.24825443]
#  [0.19825443 0.29825443]]
#
#
# Epoch 10 - Updated Weights:
#   Input to Hidden: [[0.14569419 0.19569419]
#  [0.24569419 0.29569419]]
#   Hidden to Output: [[0.12408811 0.22408811]
#  [0.17408811 0.27408811]]
#
#
# Epoch 11 - Updated Weights:
#   Input to Hidden: [[0.1455704 0.1955704]
#  [0.2455704 0.2955704]]
#   Hidden to Output: [[0.10063976 0.20063976]
#  [0.15063976 0.25063976]]
#
#
# Epoch 12 - Updated Weights:
#   Input to Hidden: [[0.14548792 0.19548792]
#  [0.24548792 0.29548792]]
#   Hidden to Output: [[0.07789579 0.17789579]
#  [0.12789579 0.22789579]]
#
#
# Epoch 13 - Updated Weights:
#   Input to Hidden: [[0.14544367 0.19544367]
#  [0.24544367 0.29544367]]
#   Hidden to Output: [[0.05584219 0.15584219]
#  [0.10584219 0.20584219]]
#
#
# Epoch 14 - Updated Weights:
#   Input to Hidden: [[0.14543473 0.19543473]
#  [0.24543473 0.29543473]]
#   Hidden to Output: [[0.03446459 0.13446459]
#  [0.08446459 0.18446459]]
#
#
# Epoch 15 - Updated Weights:
#   Input to Hidden: [[0.14545832 0.19545832]
#  [0.24545832 0.29545832]]
#   Hidden to Output: [[0.01374836 0.11374836]
#  [0.06374836 0.16374836]]
#
#
# Epoch 16 - Updated Weights:
#   Input to Hidden: [[0.14551184 0.19551184]
#  [0.24551184 0.29551184]]
#   Hidden to Output: [[-0.00632139  0.09367861]
#  [ 0.04367861  0.14367861]]
#
#
# Epoch 17 - Updated Weights:
#   Input to Hidden: [[0.14559284 0.19559284]
#  [0.24559284 0.29559284]]
#   Hidden to Output: [[-0.02575971  0.07424029]
#  [ 0.02424029  0.12424029]]
#
#
# Epoch 18 - Updated Weights:
#   Input to Hidden: [[0.14569899 0.19569899]
#  [0.24569899 0.29569899]]
#   Hidden to Output: [[-0.04458175  0.05541825]
#  [ 0.00541825  0.10541825]]
#
#
# Epoch 19 - Updated Weights:
#   Input to Hidden: [[0.14582812 0.19582812]
#  [0.24582812 0.29582812]]
#   Hidden to Output: [[-0.06280275  0.03719725]
#  [-0.01280275  0.08719725]]
#
#
# Epoch 20 - Updated Weights:
#   Input to Hidden: [[0.14597819 0.19597819]
#  [0.24597819 0.29597819]]
#   Hidden to Output: [[-0.08043797  0.01956203]
#  [-0.03043797  0.06956203]]
#
#
# Epoch 21 - Updated Weights:
#   Input to Hidden: [[0.14614731 0.19614731]
#  [0.24614731 0.29614731]]
#   Hidden to Output: [[-0.09750262  0.00249738]
#  [-0.04750262  0.05249738]]
#
#
# Epoch 22 - Updated Weights:
#   Input to Hidden: [[0.14633368 0.19633368]
#  [0.24633368 0.29633368]]
#   Hidden to Output: [[-0.11401189 -0.01401189]
#  [-0.06401189  0.03598811]]
#
#
# Epoch 23 - Updated Weights:
#   Input to Hidden: [[0.14653565 0.19653565]
#  [0.24653565 0.29653565]]
#   Hidden to Output: [[-0.12998084 -0.02998084]
#  [-0.07998084  0.02001916]]
#
#
# Epoch 24 - Updated Weights:
#   Input to Hidden: [[0.14675166 0.19675166]
#  [0.24675166 0.29675166]]
#   Hidden to Output: [[-0.14542443 -0.04542443]
#  [-0.09542443  0.00457557]]
#
#
# Epoch 25 - Updated Weights:
#   Input to Hidden: [[0.14698028 0.19698028]
#  [0.24698028 0.29698028]]
#   Hidden to Output: [[-0.16035745 -0.06035745]
#  [-0.11035745 -0.01035745]]
#
#
# Epoch 26 - Updated Weights:
#   Input to Hidden: [[0.14722017 0.19722017]
#  [0.24722017 0.29722017]]
#   Hidden to Output: [[-0.1747945 -0.0747945]
#  [-0.1247945 -0.0247945]]
#
#
# Epoch 27 - Updated Weights:
#   Input to Hidden: [[0.14747009 0.19747009]
#  [0.24747009 0.29747009]]
#   Hidden to Output: [[-0.18875 -0.08875]
#  [-0.13875 -0.03875]]
#
#
# Epoch 28 - Updated Weights:
#   Input to Hidden: [[0.14772889 0.19772889]
#  [0.24772889 0.29772889]]
#   Hidden to Output: [[-0.20223814 -0.10223814]
#  [-0.15223814 -0.05223814]]
#
#
# Epoch 29 - Updated Weights:
#   Input to Hidden: [[0.1479955 0.1979955]
#  [0.2479955 0.2979955]]
#   Hidden to Output: [[-0.21527287 -0.11527287]
#  [-0.16527287 -0.06527287]]
#
#
# Epoch 30 - Updated Weights:
#   Input to Hidden: [[0.14826896 0.19826896]
#  [0.24826896 0.29826896]]
#   Hidden to Output: [[-0.22786788 -0.12786788]
#  [-0.17786788 -0.07786788]]
#
#
# Epoch 31 - Updated Weights:
#   Input to Hidden: [[0.14854834 0.19854834]
#  [0.24854834 0.29854834]]
#   Hidden to Output: [[-0.2400366 -0.1400366]
#  [-0.1900366 -0.0900366]]
#
#
# Epoch 32 - Updated Weights:
#   Input to Hidden: [[0.14883283 0.19883283]
#  [0.24883283 0.29883283]]
#   Hidden to Output: [[-0.25179219 -0.15179219]
#  [-0.20179219 -0.10179219]]
#
#
# Epoch 33 - Updated Weights:
#   Input to Hidden: [[0.14912165 0.19912165]
#  [0.24912165 0.29912165]]
#   Hidden to Output: [[-0.26314752 -0.16314752]
#  [-0.21314752 -0.11314752]]
#
#
# Epoch 34 - Updated Weights:
#   Input to Hidden: [[0.14941411 0.19941411]
#  [0.24941411 0.29941411]]
#   Hidden to Output: [[-0.27411517 -0.17411517]
#  [-0.22411517 -0.12411517]]
#
#
# Epoch 35 - Updated Weights:
#   Input to Hidden: [[0.14970957 0.19970957]
#  [0.24970957 0.29970957]]
#   Hidden to Output: [[-0.28470743 -0.18470743]
#  [-0.23470743 -0.13470743]]
#
#
# Epoch 36 - Updated Weights:
#   Input to Hidden: [[0.15000742 0.20000742]
#  [0.25000742 0.30000742]]
#   Hidden to Output: [[-0.2949363 -0.1949363]
#  [-0.2449363 -0.1449363]]
#
#
# Epoch 37 - Updated Weights:
#   Input to Hidden: [[0.15030715 0.20030715]
#  [0.25030715 0.30030715]]
#   Hidden to Output: [[-0.30481346 -0.20481346]
#  [-0.25481346 -0.15481346]]
#
#
# Epoch 38 - Updated Weights:
#   Input to Hidden: [[0.15060826 0.20060826]
#  [0.25060826 0.30060826]]
#   Hidden to Output: [[-0.3143503 -0.2143503]
#  [-0.2643503 -0.1643503]]
#
#
# Epoch 39 - Updated Weights:
#   Input to Hidden: [[0.15091031 0.20091031]
#  [0.25091031 0.30091031]]
#   Hidden to Output: [[-0.3235579 -0.2235579]
#  [-0.2735579 -0.1735579]]
#
#
# Epoch 40 - Updated Weights:
#   Input to Hidden: [[0.1512129 0.2012129]
#  [0.2512129 0.3012129]]
#   Hidden to Output: [[-0.33244707 -0.23244707]
#  [-0.28244707 -0.18244707]]
#
#
# Epoch 41 - Updated Weights:
#   Input to Hidden: [[0.15151565 0.20151565]
#  [0.25151565 0.30151565]]
#   Hidden to Output: [[-0.34102829 -0.24102829]
#  [-0.29102829 -0.19102829]]
#
#
# Epoch 42 - Updated Weights:
#   Input to Hidden: [[0.15181826 0.20181826]
#  [0.25181826 0.30181826]]
#   Hidden to Output: [[-0.34931175 -0.24931175]
#  [-0.29931175 -0.19931175]]
#
#
# Epoch 43 - Updated Weights:
#   Input to Hidden: [[0.1521204 0.2021204]
#  [0.2521204 0.3021204]]
#   Hidden to Output: [[-0.35730736 -0.25730736]
#  [-0.30730736 -0.20730736]]
#
#
# Epoch 44 - Updated Weights:
#   Input to Hidden: [[0.15242184 0.20242184]
#  [0.25242184 0.30242184]]
#   Hidden to Output: [[-0.36502473 -0.26502473]
#  [-0.31502473 -0.21502473]]
#
#
# Epoch 45 - Updated Weights:
#   Input to Hidden: [[0.15272232 0.20272232]
#  [0.25272232 0.30272232]]
#   Hidden to Output: [[-0.37247321 -0.27247321]
#  [-0.32247321 -0.22247321]]
#
#
# Epoch 46 - Updated Weights:
#   Input to Hidden: [[0.15302163 0.20302163]
#  [0.25302163 0.30302163]]
#   Hidden to Output: [[-0.37966183 -0.27966183]
#  [-0.32966183 -0.22966183]]
#
#
# Epoch 47 - Updated Weights:
#   Input to Hidden: [[0.1533196 0.2033196]
#  [0.2533196 0.3033196]]
#   Hidden to Output: [[-0.38659938 -0.28659938]
#  [-0.33659938 -0.23659938]]
#
#
# Epoch 48 - Updated Weights:
#   Input to Hidden: [[0.15361604 0.20361604]
#  [0.25361604 0.30361604]]
#   Hidden to Output: [[-0.39329436 -0.29329436]
#  [-0.34329436 -0.24329436]]
#
#
# Epoch 49 - Updated Weights:
#   Input to Hidden: [[0.15391083 0.20391083]
#  [0.25391083 0.30391083]]
#   Hidden to Output: [[-0.39975503 -0.29975503]
#  [-0.34975503 -0.24975503]]
#
#
# Epoch 50 - Updated Weights:
#   Input to Hidden: [[0.15420382 0.20420382]
#  [0.25420382 0.30420382]]
#   Hidden to Output: [[-0.40598937 -0.30598937]
#  [-0.35598937 -0.25598937]]
#
#
# Epoch 51 - Updated Weights:
#   Input to Hidden: [[0.15449492 0.20449492]
#  [0.25449492 0.30449492]]
#   Hidden to Output: [[-0.41200511 -0.31200511]
#  [-0.36200511 -0.26200511]]
#
#
# Epoch 52 - Updated Weights:
#   Input to Hidden: [[0.15478403 0.20478403]
#  [0.25478403 0.30478403]]
#   Hidden to Output: [[-0.41780974 -0.31780974]
#  [-0.36780974 -0.26780974]]
#
#
# Epoch 53 - Updated Weights:
#   Input to Hidden: [[0.15507107 0.20507107]
#  [0.25507107 0.30507107]]
#   Hidden to Output: [[-0.42341052 -0.32341052]
#  [-0.37341052 -0.27341052]]
#
#
# Epoch 54 - Updated Weights:
#   Input to Hidden: [[0.15535597 0.20535597]
#  [0.25535597 0.30535597]]
#   Hidden to Output: [[-0.42881445 -0.32881445]
#  [-0.37881445 -0.27881445]]
#
#
# Epoch 55 - Updated Weights:
#   Input to Hidden: [[0.15563868 0.20563868]
#  [0.25563868 0.30563868]]
#   Hidden to Output: [[-0.43402833 -0.33402833]
#  [-0.38402833 -0.28402833]]
#
#
# Epoch 56 - Updated Weights:
#   Input to Hidden: [[0.15591916 0.20591916]
#  [0.25591916 0.30591916]]
#   Hidden to Output: [[-0.43905871 -0.33905871]
#  [-0.38905871 -0.28905871]]
#
#
# Epoch 57 - Updated Weights:
#   Input to Hidden: [[0.15619737 0.20619737]
#  [0.25619737 0.30619737]]
#   Hidden to Output: [[-0.44391196 -0.34391196]
#  [-0.39391196 -0.29391196]]
#
#
# Epoch 58 - Updated Weights:
#   Input to Hidden: [[0.15647328 0.20647328]
#  [0.25647328 0.30647328]]
#   Hidden to Output: [[-0.4485942 -0.3485942]
#  [-0.3985942 -0.2985942]]
#
#
# Epoch 59 - Updated Weights:
#   Input to Hidden: [[0.15674689 0.20674689]
#  [0.25674689 0.30674689]]
#   Hidden to Output: [[-0.45311137 -0.35311137]
#  [-0.40311137 -0.30311137]]
#
#
# Epoch 60 - Updated Weights:
#   Input to Hidden: [[0.15701818 0.20701818]
#  [0.25701818 0.30701818]]
#   Hidden to Output: [[-0.45746921 -0.35746921]
#  [-0.40746921 -0.30746921]]
#
#
# Epoch 61 - Updated Weights:
#   Input to Hidden: [[0.15728715 0.20728715]
#  [0.25728715 0.30728715]]
#   Hidden to Output: [[-0.46167327 -0.36167327]
#  [-0.41167327 -0.31167327]]
#
#
# Epoch 62 - Updated Weights:
#   Input to Hidden: [[0.1575538 0.2075538]
#  [0.2575538 0.3075538]]
#   Hidden to Output: [[-0.46572891 -0.36572891]
#  [-0.41572891 -0.31572891]]
#
#
# Epoch 63 - Updated Weights:
#   Input to Hidden: [[0.15781814 0.20781814]
#  [0.25781814 0.30781814]]
#   Hidden to Output: [[-0.46964129 -0.36964129]
#  [-0.41964129 -0.31964129]]
#
#
# Epoch 64 - Updated Weights:
#   Input to Hidden: [[0.15808019 0.20808019]
#  [0.25808019 0.30808019]]
#   Hidden to Output: [[-0.47341543 -0.37341543]
#  [-0.42341543 -0.32341543]]
#
#
# Epoch 65 - Updated Weights:
#   Input to Hidden: [[0.15833996 0.20833996]
#  [0.25833996 0.30833996]]
#   Hidden to Output: [[-0.47705615 -0.37705615]
#  [-0.42705615 -0.32705615]]
#
#
# Epoch 66 - Updated Weights:
#   Input to Hidden: [[0.15859747 0.20859747]
#  [0.25859747 0.30859747]]
#   Hidden to Output: [[-0.48056813 -0.38056813]
#  [-0.43056813 -0.33056813]]
#
#
# Epoch 67 - Updated Weights:
#   Input to Hidden: [[0.15885275 0.20885275]
#  [0.25885275 0.30885275]]
#   Hidden to Output: [[-0.48395588 -0.38395588]
#  [-0.43395588 -0.33395588]]
#
#
# Epoch 68 - Updated Weights:
#   Input to Hidden: [[0.15910583 0.20910583]
#  [0.25910583 0.30910583]]
#   Hidden to Output: [[-0.48722374 -0.38722374]
#  [-0.43722374 -0.33722374]]
#
#
# Epoch 69 - Updated Weights:
#   Input to Hidden: [[0.15935674 0.20935674]
#  [0.25935674 0.30935674]]
#   Hidden to Output: [[-0.49037592 -0.39037592]
#  [-0.44037592 -0.34037592]]
#
#
# Epoch 70 - Updated Weights:
#   Input to Hidden: [[0.15960551 0.20960551]
#  [0.25960551 0.30960551]]
#   Hidden to Output: [[-0.49341648 -0.39341648]
#  [-0.44341648 -0.34341648]]
#
#
# Epoch 71 - Updated Weights:
#   Input to Hidden: [[0.15985217 0.20985217]
#  [0.25985217 0.30985217]]
#   Hidden to Output: [[-0.49634935 -0.39634935]
#  [-0.44634935 -0.34634935]]
#
#
# Epoch 72 - Updated Weights:
#   Input to Hidden: [[0.16009676 0.21009676]
#  [0.26009676 0.31009676]]
#   Hidden to Output: [[-0.4991783 -0.3991783]
#  [-0.4491783 -0.3491783]]
#
#
# Epoch 73 - Updated Weights:
#   Input to Hidden: [[0.16033932 0.21033932]
#  [0.26033932 0.31033932]]
#   Hidden to Output: [[-0.50190699 -0.40190699]
#  [-0.45190699 -0.35190699]]
#
#
# Epoch 74 - Updated Weights:
#   Input to Hidden: [[0.16057989 0.21057989]
#  [0.26057989 0.31057989]]
#   Hidden to Output: [[-0.50453896 -0.40453896]
#  [-0.45453896 -0.35453896]]
#
#
# Epoch 75 - Updated Weights:
#   Input to Hidden: [[0.1608185 0.2108185]
#  [0.2608185 0.3108185]]
#   Hidden to Output: [[-0.50707759 -0.40707759]
#  [-0.45707759 -0.35707759]]
#
#
# Epoch 76 - Updated Weights:
#   Input to Hidden: [[0.16105521 0.21105521]
#  [0.26105521 0.31105521]]
#   Hidden to Output: [[-0.50952619 -0.40952619]
#  [-0.45952619 -0.35952619]]
#
#
# Epoch 77 - Updated Weights:
#   Input to Hidden: [[0.16129004 0.21129004]
#  [0.26129004 0.31129004]]
#   Hidden to Output: [[-0.51188792 -0.41188792]
#  [-0.46188792 -0.36188792]]
#
#
# Epoch 78 - Updated Weights:
#   Input to Hidden: [[0.16152304 0.21152304]
#  [0.26152304 0.31152304]]
#   Hidden to Output: [[-0.51416585 -0.41416585]
#  [-0.46416585 -0.36416585]]
#
#
# Epoch 79 - Updated Weights:
#   Input to Hidden: [[0.16175425 0.21175425]
#  [0.26175425 0.31175425]]
#   Hidden to Output: [[-0.51636292 -0.41636292]
#  [-0.46636292 -0.36636292]]
#
#
# Epoch 80 - Updated Weights:
#   Input to Hidden: [[0.16198372 0.21198372]
#  [0.26198372 0.31198372]]
#   Hidden to Output: [[-0.518482 -0.418482]
#  [-0.468482 -0.368482]]
#
#
# Epoch 81 - Updated Weights:
#   Input to Hidden: [[0.16221148 0.21221148]
#  [0.26221148 0.31221148]]
#   Hidden to Output: [[-0.52052583 -0.42052583]
#  [-0.47052583 -0.37052583]]
#
#
# Epoch 82 - Updated Weights:
#   Input to Hidden: [[0.16243758 0.21243758]
#  [0.26243758 0.31243758]]
#   Hidden to Output: [[-0.52249708 -0.42249708]
#  [-0.47249708 -0.37249708]]
#
#
# Epoch 83 - Updated Weights:
#   Input to Hidden: [[0.16266206 0.21266206]
#  [0.26266206 0.31266206]]
#   Hidden to Output: [[-0.52439829 -0.42439829]
#  [-0.47439829 -0.37439829]]
#
#
# Epoch 84 - Updated Weights:
#   Input to Hidden: [[0.16288496 0.21288496]
#  [0.26288496 0.31288496]]
#   Hidden to Output: [[-0.52623195 -0.42623195]
#  [-0.47623195 -0.37623195]]
#
#
# Epoch 85 - Updated Weights:
#   Input to Hidden: [[0.16310632 0.21310632]
#  [0.26310632 0.31310632]]
#   Hidden to Output: [[-0.52800045 -0.42800045]
#  [-0.47800045 -0.37800045]]
#
#
# Epoch 86 - Updated Weights:
#   Input to Hidden: [[0.16332618 0.21332618]
#  [0.26332618 0.31332618]]
#   Hidden to Output: [[-0.52970608 -0.42970608]
#  [-0.47970608 -0.37970608]]
#
#
# Epoch 87 - Updated Weights:
#   Input to Hidden: [[0.16354458 0.21354458]
#  [0.26354458 0.31354458]]
#   Hidden to Output: [[-0.53135108 -0.43135108]
#  [-0.48135108 -0.38135108]]
#
#
# Epoch 88 - Updated Weights:
#   Input to Hidden: [[0.16376157 0.21376157]
#  [0.26376157 0.31376157]]
#   Hidden to Output: [[-0.53293757 -0.43293757]
#  [-0.48293757 -0.38293757]]
#
#
# Epoch 89 - Updated Weights:
#   Input to Hidden: [[0.16397718 0.21397718]
#  [0.26397718 0.31397718]]
#   Hidden to Output: [[-0.53446764 -0.43446764]
#  [-0.48446764 -0.38446764]]
#
#
# Epoch 90 - Updated Weights:
#   Input to Hidden: [[0.16419144 0.21419144]
#  [0.26419144 0.31419144]]
#   Hidden to Output: [[-0.53594327 -0.43594327]
#  [-0.48594327 -0.38594327]]
#
#
# Epoch 91 - Updated Weights:
#   Input to Hidden: [[0.16440441 0.21440441]
#  [0.26440441 0.31440441]]
#   Hidden to Output: [[-0.5373664 -0.4373664]
#  [-0.4873664 -0.3873664]]
#
#
# Epoch 92 - Updated Weights:
#   Input to Hidden: [[0.16461611 0.21461611]
#  [0.26461611 0.31461611]]
#   Hidden to Output: [[-0.53873887 -0.43873887]
#  [-0.48873887 -0.38873887]]
#
#
# Epoch 93 - Updated Weights:
#   Input to Hidden: [[0.16482657 0.21482657]
#  [0.26482657 0.31482657]]
#   Hidden to Output: [[-0.54006249 -0.44006249]
#  [-0.49006249 -0.39006249]]
#
#
# Epoch 94 - Updated Weights:
#   Input to Hidden: [[0.16503585 0.21503585]
#  [0.26503585 0.31503585]]
#   Hidden to Output: [[-0.54133898 -0.44133898]
#  [-0.49133898 -0.39133898]]
#
#
# Epoch 95 - Updated Weights:
#   Input to Hidden: [[0.16524397 0.21524397]
#  [0.26524397 0.31524397]]
#   Hidden to Output: [[-0.54257001 -0.44257001]
#  [-0.49257001 -0.39257001]]
#
#
# Epoch 96 - Updated Weights:
#   Input to Hidden: [[0.16545096 0.21545096]
#  [0.26545096 0.31545096]]
#   Hidden to Output: [[-0.5437572 -0.4437572]
#  [-0.4937572 -0.3937572]]
#
#
# Epoch 97 - Updated Weights:
#   Input to Hidden: [[0.16565686 0.21565686]
#  [0.26565686 0.31565686]]
#   Hidden to Output: [[-0.54490208 -0.44490208]
#  [-0.49490208 -0.39490208]]
#
#
# Epoch 98 - Updated Weights:
#   Input to Hidden: [[0.16586171 0.21586171]
#  [0.26586171 0.31586171]]
#   Hidden to Output: [[-0.54600617 -0.44600617]
#  [-0.49600617 -0.39600617]]
#
#
# Epoch 99 - Updated Weights:
#   Input to Hidden: [[0.16606553 0.21606553]
#  [0.26606553 0.31606553]]
#   Hidden to Output: [[-0.5470709 -0.4470709]
#  [-0.4970709 -0.3970709]]
#
#
# Epoch 100 - Updated Weights:
#   Input to Hidden: [[0.16626835 0.21626835]
#  [0.26626835 0.31626835]]
#   Hidden to Output: [[-0.54809767 -0.44809767]
#  [-0.49809767 -0.39809767]]
#
#
# Epoch 101 - Updated Weights:
#   Input to Hidden: [[0.16647021 0.21647021]
#  [0.26647021 0.31647021]]
#   Hidden to Output: [[-0.54908782 -0.44908782]
#  [-0.49908782 -0.39908782]]
#
#
# Epoch 102 - Updated Weights:
#   Input to Hidden: [[0.16667114 0.21667114]
#  [0.26667114 0.31667114]]
#   Hidden to Output: [[-0.55004266 -0.45004266]
#  [-0.50004266 -0.40004266]]
#
#
# Epoch 103 - Updated Weights:
#   Input to Hidden: [[0.16687116 0.21687116]
#  [0.26687116 0.31687116]]
#   Hidden to Output: [[-0.55096343 -0.45096343]
#  [-0.50096343 -0.40096343]]
#
#
# Epoch 104 - Updated Weights:
#   Input to Hidden: [[0.16707031 0.21707031]
#  [0.26707031 0.31707031]]
#   Hidden to Output: [[-0.55185134 -0.45185134]
#  [-0.50185134 -0.40185134]]
#
#
# Epoch 105 - Updated Weights:
#   Input to Hidden: [[0.1672686 0.2172686]
#  [0.2672686 0.3172686]]
#   Hidden to Output: [[-0.55270756 -0.45270756]
#  [-0.50270756 -0.40270756]]
#
#
# Epoch 106 - Updated Weights:
#   Input to Hidden: [[0.16746608 0.21746608]
#  [0.26746608 0.31746608]]
#   Hidden to Output: [[-0.5535332 -0.4535332]
#  [-0.5035332 -0.4035332]]
#
#
# Epoch 107 - Updated Weights:
#   Input to Hidden: [[0.16766276 0.21766276]
#  [0.26766276 0.31766276]]
#   Hidden to Output: [[-0.55432936 -0.45432936]
#  [-0.50432936 -0.40432936]]
#
#
# Epoch 108 - Updated Weights:
#   Input to Hidden: [[0.16785867 0.21785867]
#  [0.26785867 0.31785867]]
#   Hidden to Output: [[-0.55509707 -0.45509707]
#  [-0.50509707 -0.40509707]]
#
#
# Epoch 109 - Updated Weights:
#   Input to Hidden: [[0.16805383 0.21805383]
#  [0.26805383 0.31805383]]
#   Hidden to Output: [[-0.55583735 -0.45583735]
#  [-0.50583735 -0.40583735]]
#
#
# Epoch 110 - Updated Weights:
#   Input to Hidden: [[0.16824827 0.21824827]
#  [0.26824827 0.31824827]]
#   Hidden to Output: [[-0.55655117 -0.45655117]
#  [-0.50655117 -0.40655117]]
#
#
# Epoch 111 - Updated Weights:
#   Input to Hidden: [[0.16844201 0.21844201]
#  [0.26844201 0.31844201]]
#   Hidden to Output: [[-0.55723946 -0.45723946]
#  [-0.50723946 -0.40723946]]
#
#
# Epoch 112 - Updated Weights:
#   Input to Hidden: [[0.16863508 0.21863508]
#  [0.26863508 0.31863508]]
#   Hidden to Output: [[-0.55790314 -0.45790314]
#  [-0.50790314 -0.40790314]]
#
#
# Epoch 113 - Updated Weights:
#   Input to Hidden: [[0.16882749 0.21882749]
#  [0.26882749 0.31882749]]
#   Hidden to Output: [[-0.55854307 -0.45854307]
#  [-0.50854307 -0.40854307]]
#
#
# Epoch 114 - Updated Weights:
#   Input to Hidden: [[0.16901927 0.21901927]
#  [0.26901927 0.31901927]]
#   Hidden to Output: [[-0.55916009 -0.45916009]
#  [-0.50916009 -0.40916009]]
#
#
# Epoch 115 - Updated Weights:
#   Input to Hidden: [[0.16921043 0.21921043]
#  [0.26921043 0.31921043]]
#   Hidden to Output: [[-0.55975503 -0.45975503]
#  [-0.50975503 -0.40975503]]
#
#
# Epoch 116 - Updated Weights:
#   Input to Hidden: [[0.16940101 0.21940101]
#  [0.26940101 0.31940101]]
#   Hidden to Output: [[-0.56032866 -0.46032866]
#  [-0.51032866 -0.41032866]]
#
#
# Epoch 117 - Updated Weights:
#   Input to Hidden: [[0.16959101 0.21959101]
#  [0.26959101 0.31959101]]
#   Hidden to Output: [[-0.56088174 -0.46088174]
#  [-0.51088174 -0.41088174]]
#
#
# Epoch 118 - Updated Weights:
#   Input to Hidden: [[0.16978046 0.21978046]
#  [0.26978046 0.31978046]]
#   Hidden to Output: [[-0.56141499 -0.46141499]
#  [-0.51141499 -0.41141499]]
#
#
# Epoch 119 - Updated Weights:
#   Input to Hidden: [[0.16996938 0.21996938]
#  [0.26996938 0.31996938]]
#   Hidden to Output: [[-0.56192912 -0.46192912]
#  [-0.51192912 -0.41192912]]
#
#
# Epoch 120 - Updated Weights:
#   Input to Hidden: [[0.17015777 0.22015777]
#  [0.27015777 0.32015777]]
#   Hidden to Output: [[-0.56242482 -0.46242482]
#  [-0.51242482 -0.41242482]]
#
#
# Epoch 121 - Updated Weights:
#   Input to Hidden: [[0.17034567 0.22034567]
#  [0.27034567 0.32034567]]
#   Hidden to Output: [[-0.56290272 -0.46290272]
#  [-0.51290272 -0.41290272]]
#
#
# Epoch 122 - Updated Weights:
#   Input to Hidden: [[0.17053308 0.22053308]
#  [0.27053308 0.32053308]]
#   Hidden to Output: [[-0.56336347 -0.46336347]
#  [-0.51336347 -0.41336347]]
#
#
# Epoch 123 - Updated Weights:
#   Input to Hidden: [[0.17072003 0.22072003]
#  [0.27072003 0.32072003]]
#   Hidden to Output: [[-0.56380768 -0.46380768]
#  [-0.51380768 -0.41380768]]
#
#
# Epoch 124 - Updated Weights:
#   Input to Hidden: [[0.17090653 0.22090653]
#  [0.27090653 0.32090653]]
#   Hidden to Output: [[-0.56423592 -0.46423592]
#  [-0.51423592 -0.41423592]]
#
#
# Epoch 125 - Updated Weights:
#   Input to Hidden: [[0.17109259 0.22109259]
#  [0.27109259 0.32109259]]
#   Hidden to Output: [[-0.56464877 -0.46464877]
#  [-0.51464877 -0.41464877]]
#
#
# Epoch 126 - Updated Weights:
#   Input to Hidden: [[0.17127822 0.22127822]
#  [0.27127822 0.32127822]]
#   Hidden to Output: [[-0.56504677 -0.46504677]
#  [-0.51504677 -0.41504677]]
#
#
# Epoch 127 - Updated Weights:
#   Input to Hidden: [[0.17146345 0.22146345]
#  [0.27146345 0.32146345]]
#   Hidden to Output: [[-0.56543045 -0.46543045]
#  [-0.51543045 -0.41543045]]
#
#
# Epoch 128 - Updated Weights:
#   Input to Hidden: [[0.17164829 0.22164829]
#  [0.27164829 0.32164829]]
#   Hidden to Output: [[-0.56580032 -0.46580032]
#  [-0.51580032 -0.41580032]]
#
#
# Epoch 129 - Updated Weights:
#   Input to Hidden: [[0.17183275 0.22183275]
#  [0.27183275 0.32183275]]
#   Hidden to Output: [[-0.56615686 -0.46615686]
#  [-0.51615686 -0.41615686]]
#
#
# Epoch 130 - Updated Weights:
#   Input to Hidden: [[0.17201683 0.22201683]
#  [0.27201683 0.32201683]]
#   Hidden to Output: [[-0.56650056 -0.46650056]
#  [-0.51650056 -0.41650056]]
#
#
# Epoch 131 - Updated Weights:
#   Input to Hidden: [[0.17220057 0.22220057]
#  [0.27220057 0.32220057]]
#   Hidden to Output: [[-0.56683186 -0.46683186]
#  [-0.51683186 -0.41683186]]
#
#
# Epoch 132 - Updated Weights:
#   Input to Hidden: [[0.17238396 0.22238396]
#  [0.27238396 0.32238396]]
#   Hidden to Output: [[-0.56715121 -0.46715121]
#  [-0.51715121 -0.41715121]]
#
#
# Epoch 133 - Updated Weights:
#   Input to Hidden: [[0.17256702 0.22256702]
#  [0.27256702 0.32256702]]
#   Hidden to Output: [[-0.56745903 -0.46745903]
#  [-0.51745903 -0.41745903]]
#
#
# Epoch 134 - Updated Weights:
#   Input to Hidden: [[0.17274976 0.22274976]
#  [0.27274976 0.32274976]]
#   Hidden to Output: [[-0.56775573 -0.46775573]
#  [-0.51775573 -0.41775573]]
#
#
# Epoch 135 - Updated Weights:
#   Input to Hidden: [[0.17293219 0.22293219]
#  [0.27293219 0.32293219]]
#   Hidden to Output: [[-0.5680417 -0.4680417]
#  [-0.5180417 -0.4180417]]
#
#
# Epoch 136 - Updated Weights:
#   Input to Hidden: [[0.17311432 0.22311432]
#  [0.27311432 0.32311432]]
#   Hidden to Output: [[-0.56831733 -0.46831733]
#  [-0.51831733 -0.41831733]]
#
#
# Epoch 137 - Updated Weights:
#   Input to Hidden: [[0.17329617 0.22329617]
#  [0.27329617 0.32329617]]
#   Hidden to Output: [[-0.56858298 -0.46858298]
#  [-0.51858298 -0.41858298]]
#
#
# Epoch 138 - Updated Weights:
#   Input to Hidden: [[0.17347773 0.22347773]
#  [0.27347773 0.32347773]]
#   Hidden to Output: [[-0.56883901 -0.46883901]
#  [-0.51883901 -0.41883901]]
#
#
# Epoch 139 - Updated Weights:
#   Input to Hidden: [[0.17365903 0.22365903]
#  [0.27365903 0.32365903]]
#   Hidden to Output: [[-0.56908576 -0.46908576]
#  [-0.51908576 -0.41908576]]
#
#
# Epoch 140 - Updated Weights:
#   Input to Hidden: [[0.17384007 0.22384007]
#  [0.27384007 0.32384007]]
#   Hidden to Output: [[-0.56932355 -0.46932355]
#  [-0.51932355 -0.41932355]]
#
#
# Epoch 141 - Updated Weights:
#   Input to Hidden: [[0.17402085 0.22402085]
#  [0.27402085 0.32402085]]
#   Hidden to Output: [[-0.56955271 -0.46955271]
#  [-0.51955271 -0.41955271]]
#
#
# Epoch 142 - Updated Weights:
#   Input to Hidden: [[0.1742014 0.2242014]
#  [0.2742014 0.3242014]]
#   Hidden to Output: [[-0.56977354 -0.46977354]
#  [-0.51977354 -0.41977354]]
#
#
# Epoch 143 - Updated Weights:
#   Input to Hidden: [[0.17438171 0.22438171]
#  [0.27438171 0.32438171]]
#   Hidden to Output: [[-0.56998634 -0.46998634]
#  [-0.51998634 -0.41998634]]
#
#
# Epoch 144 - Updated Weights:
#   Input to Hidden: [[0.1745618 0.2245618]
#  [0.2745618 0.3245618]]
#   Hidden to Output: [[-0.5701914 -0.4701914]
#  [-0.5201914 -0.4201914]]
#
#
# Epoch 145 - Updated Weights:
#   Input to Hidden: [[0.17474167 0.22474167]
#  [0.27474167 0.32474167]]
#   Hidden to Output: [[-0.57038898 -0.47038898]
#  [-0.52038898 -0.42038898]]
#
#
# Epoch 146 - Updated Weights:
#   Input to Hidden: [[0.17492132 0.22492132]
#  [0.27492132 0.32492132]]
#   Hidden to Output: [[-0.57057935 -0.47057935]
#  [-0.52057935 -0.42057935]]
#
#
# Epoch 147 - Updated Weights:
#   Input to Hidden: [[0.17510078 0.22510078]
#  [0.27510078 0.32510078]]
#   Hidden to Output: [[-0.57076278 -0.47076278]
#  [-0.52076278 -0.42076278]]
#
#
# Epoch 148 - Updated Weights:
#   Input to Hidden: [[0.17528004 0.22528004]
#  [0.27528004 0.32528004]]
#   Hidden to Output: [[-0.5709395 -0.4709395]
#  [-0.5209395 -0.4209395]]
#
#
# Epoch 149 - Updated Weights:
#   Input to Hidden: [[0.17545911 0.22545911]
#  [0.27545911 0.32545911]]
#   Hidden to Output: [[-0.57110975 -0.47110975]
#  [-0.52110975 -0.42110975]]
#
#
# Epoch 150 - Updated Weights:
#   Input to Hidden: [[0.175638 0.225638]
#  [0.275638 0.325638]]
#   Hidden to Output: [[-0.57127377 -0.47127377]
#  [-0.52127377 -0.42127377]]
#
#
# Epoch 151 - Updated Weights:
#   Input to Hidden: [[0.17581671 0.22581671]
#  [0.27581671 0.32581671]]
#   Hidden to Output: [[-0.57143178 -0.47143178]
#  [-0.52143178 -0.42143178]]
#
#
# Epoch 152 - Updated Weights:
#   Input to Hidden: [[0.17599525 0.22599525]
#  [0.27599525 0.32599525]]
#   Hidden to Output: [[-0.57158398 -0.47158398]
#  [-0.52158398 -0.42158398]]
#
#
# Epoch 153 - Updated Weights:
#   Input to Hidden: [[0.17617363 0.22617363]
#  [0.27617363 0.32617363]]
#   Hidden to Output: [[-0.57173059 -0.47173059]
#  [-0.52173059 -0.42173059]]
#
#
# Epoch 154 - Updated Weights:
#   Input to Hidden: [[0.17635184 0.22635184]
#  [0.27635184 0.32635184]]
#   Hidden to Output: [[-0.5718718 -0.4718718]
#  [-0.5218718 -0.4218718]]
#
#
# Epoch 155 - Updated Weights:
#   Input to Hidden: [[0.17652991 0.22652991]
#  [0.27652991 0.32652991]]
#   Hidden to Output: [[-0.57200781 -0.47200781]
#  [-0.52200781 -0.42200781]]
#
#
# Epoch 156 - Updated Weights:
#   Input to Hidden: [[0.17670783 0.22670783]
#  [0.27670783 0.32670783]]
#   Hidden to Output: [[-0.5721388 -0.4721388]
#  [-0.5221388 -0.4221388]]
#
#
# Epoch 157 - Updated Weights:
#   Input to Hidden: [[0.1768856 0.2268856]
#  [0.2768856 0.3268856]]
#   Hidden to Output: [[-0.57226494 -0.47226494]
#  [-0.52226494 -0.42226494]]
#
#
# Epoch 158 - Updated Weights:
#   Input to Hidden: [[0.17706324 0.22706324]
#  [0.27706324 0.32706324]]
#   Hidden to Output: [[-0.57238642 -0.47238642]
#  [-0.52238642 -0.42238642]]
#
#
# Epoch 159 - Updated Weights:
#   Input to Hidden: [[0.17724074 0.22724074]
#  [0.27724074 0.32724074]]
#   Hidden to Output: [[-0.57250339 -0.47250339]
#  [-0.52250339 -0.42250339]]
#
#
# Epoch 160 - Updated Weights:
#   Input to Hidden: [[0.17741812 0.22741812]
#  [0.27741812 0.32741812]]
#   Hidden to Output: [[-0.57261602 -0.47261602]
#  [-0.52261602 -0.42261602]]
#
#
# Epoch 161 - Updated Weights:
#   Input to Hidden: [[0.17759537 0.22759537]
#  [0.27759537 0.32759537]]
#   Hidden to Output: [[-0.57272446 -0.47272446]
#  [-0.52272446 -0.42272446]]
#
#
# Epoch 162 - Updated Weights:
#   Input to Hidden: [[0.17777251 0.22777251]
#  [0.27777251 0.32777251]]
#   Hidden to Output: [[-0.57282886 -0.47282886]
#  [-0.52282886 -0.42282886]]
#
#
# Epoch 163 - Updated Weights:
#   Input to Hidden: [[0.17794952 0.22794952]
#  [0.27794952 0.32794952]]
#   Hidden to Output: [[-0.57292936 -0.47292936]
#  [-0.52292936 -0.42292936]]
#
#
# Epoch 164 - Updated Weights:
#   Input to Hidden: [[0.17812643 0.22812643]
#  [0.27812643 0.32812643]]
#   Hidden to Output: [[-0.5730261 -0.4730261]
#  [-0.5230261 -0.4230261]]
#
#
# Epoch 165 - Updated Weights:
#   Input to Hidden: [[0.17830323 0.22830323]
#  [0.27830323 0.32830323]]
#   Hidden to Output: [[-0.57311922 -0.47311922]
#  [-0.52311922 -0.42311922]]
#
#
# Epoch 166 - Updated Weights:
#   Input to Hidden: [[0.17847992 0.22847992]
#  [0.27847992 0.32847992]]
#   Hidden to Output: [[-0.57320884 -0.47320884]
#  [-0.52320884 -0.42320884]]
#
#
# Epoch 167 - Updated Weights:
#   Input to Hidden: [[0.17865652 0.22865652]
#  [0.27865652 0.32865652]]
#   Hidden to Output: [[-0.57329509 -0.47329509]
#  [-0.52329509 -0.42329509]]
#
#
# Epoch 168 - Updated Weights:
#   Input to Hidden: [[0.17883302 0.22883302]
#  [0.27883302 0.32883302]]
#   Hidden to Output: [[-0.57337809 -0.47337809]
#  [-0.52337809 -0.42337809]]
#
#
# Epoch 169 - Updated Weights:
#   Input to Hidden: [[0.17900942 0.22900942]
#  [0.27900942 0.32900942]]
#   Hidden to Output: [[-0.57345795 -0.47345795]
#  [-0.52345795 -0.42345795]]
#
#
# Epoch 170 - Updated Weights:
#   Input to Hidden: [[0.17918574 0.22918574]
#  [0.27918574 0.32918574]]
#   Hidden to Output: [[-0.57353479 -0.47353479]
#  [-0.52353479 -0.42353479]]
#
#
# Epoch 171 - Updated Weights:
#   Input to Hidden: [[0.17936197 0.22936197]
#  [0.27936197 0.32936197]]
#   Hidden to Output: [[-0.57360871 -0.47360871]
#  [-0.52360871 -0.42360871]]
#
#
# Epoch 172 - Updated Weights:
#   Input to Hidden: [[0.17953811 0.22953811]
#  [0.27953811 0.32953811]]
#   Hidden to Output: [[-0.57367981 -0.47367981]
#  [-0.52367981 -0.42367981]]
#
#
# Epoch 173 - Updated Weights:
#   Input to Hidden: [[0.17971418 0.22971418]
#  [0.27971418 0.32971418]]
#   Hidden to Output: [[-0.5737482 -0.4737482]
#  [-0.5237482 -0.4237482]]
#
#
# Epoch 174 - Updated Weights:
#   Input to Hidden: [[0.17989016 0.22989016]
#  [0.27989016 0.32989016]]
#   Hidden to Output: [[-0.57381397 -0.47381397]
#  [-0.52381397 -0.42381397]]
#
#
# Epoch 175 - Updated Weights:
#   Input to Hidden: [[0.18006607 0.23006607]
#  [0.28006607 0.33006607]]
#   Hidden to Output: [[-0.57387722 -0.47387722]
#  [-0.52387722 -0.42387722]]
#
#
# Epoch 176 - Updated Weights:
#   Input to Hidden: [[0.18024191 0.23024191]
#  [0.28024191 0.33024191]]
#   Hidden to Output: [[-0.57393803 -0.47393803]
#  [-0.52393803 -0.42393803]]
#
#
# Epoch 177 - Updated Weights:
#   Input to Hidden: [[0.18041768 0.23041768]
#  [0.28041768 0.33041768]]
#   Hidden to Output: [[-0.5739965 -0.4739965]
#  [-0.5239965 -0.4239965]]
#
#
# Epoch 178 - Updated Weights:
#   Input to Hidden: [[0.18059338 0.23059338]
#  [0.28059338 0.33059338]]
#   Hidden to Output: [[-0.5740527 -0.4740527]
#  [-0.5240527 -0.4240527]]
#
#
# Epoch 179 - Updated Weights:
#   Input to Hidden: [[0.18076901 0.23076901]
#  [0.28076901 0.33076901]]
#   Hidden to Output: [[-0.57410671 -0.47410671]
#  [-0.52410671 -0.42410671]]
#
#
# Epoch 180 - Updated Weights:
#   Input to Hidden: [[0.18094458 0.23094458]
#  [0.28094458 0.33094458]]
#   Hidden to Output: [[-0.57415862 -0.47415862]
#  [-0.52415862 -0.42415862]]
#
#
# Epoch 181 - Updated Weights:
#   Input to Hidden: [[0.18112009 0.23112009]
#  [0.28112009 0.33112009]]
#   Hidden to Output: [[-0.5742085 -0.4742085]
#  [-0.5242085 -0.4242085]]
#
#
# Epoch 182 - Updated Weights:
#   Input to Hidden: [[0.18129554 0.23129554]
#  [0.28129554 0.33129554]]
#   Hidden to Output: [[-0.57425642 -0.47425642]
#  [-0.52425642 -0.42425642]]
#
#
# Epoch 183 - Updated Weights:
#   Input to Hidden: [[0.18147094 0.23147094]
#  [0.28147094 0.33147094]]
#   Hidden to Output: [[-0.57430244 -0.47430244]
#  [-0.52430244 -0.42430244]]
#
#
# Epoch 184 - Updated Weights:
#   Input to Hidden: [[0.18164628 0.23164628]
#  [0.28164628 0.33164628]]
#   Hidden to Output: [[-0.57434665 -0.47434665]
#  [-0.52434665 -0.42434665]]
#
#
# Epoch 185 - Updated Weights:
#   Input to Hidden: [[0.18182157 0.23182157]
#  [0.28182157 0.33182157]]
#   Hidden to Output: [[-0.57438909 -0.47438909]
#  [-0.52438909 -0.42438909]]
#
#
# Epoch 186 - Updated Weights:
#   Input to Hidden: [[0.1819968 0.2319968]
#  [0.2819968 0.3319968]]
#   Hidden to Output: [[-0.57442984 -0.47442984]
#  [-0.52442984 -0.42442984]]
#
#
# Epoch 187 - Updated Weights:
#   Input to Hidden: [[0.18217199 0.23217199]
#  [0.28217199 0.33217199]]
#   Hidden to Output: [[-0.57446896 -0.47446896]
#  [-0.52446896 -0.42446896]]
#
#
# Epoch 188 - Updated Weights:
#   Input to Hidden: [[0.18234713 0.23234713]
#  [0.28234713 0.33234713]]
#   Hidden to Output: [[-0.57450649 -0.47450649]
#  [-0.52450649 -0.42450649]]
#
#
# Epoch 189 - Updated Weights:
#   Input to Hidden: [[0.18252222 0.23252222]
#  [0.28252222 0.33252222]]
#   Hidden to Output: [[-0.57454251 -0.47454251]
#  [-0.52454251 -0.42454251]]
#
#
# Epoch 190 - Updated Weights:
#   Input to Hidden: [[0.18269727 0.23269727]
#  [0.28269727 0.33269727]]
#   Hidden to Output: [[-0.57457706 -0.47457706]
#  [-0.52457706 -0.42457706]]
#
#
# Epoch 191 - Updated Weights:
#   Input to Hidden: [[0.18287228 0.23287228]
#  [0.28287228 0.33287228]]
#   Hidden to Output: [[-0.57461019 -0.47461019]
#  [-0.52461019 -0.42461019]]
#
#
# Epoch 192 - Updated Weights:
#   Input to Hidden: [[0.18304724 0.23304724]
#  [0.28304724 0.33304724]]
#   Hidden to Output: [[-0.57464196 -0.47464196]
#  [-0.52464196 -0.42464196]]
#
#
# Epoch 193 - Updated Weights:
#   Input to Hidden: [[0.18322217 0.23322217]
#  [0.28322217 0.33322217]]
#   Hidden to Output: [[-0.57467242 -0.47467242]
#  [-0.52467242 -0.42467242]]
#
#
# Epoch 194 - Updated Weights:
#   Input to Hidden: [[0.18339705 0.23339705]
#  [0.28339705 0.33339705]]
#   Hidden to Output: [[-0.5747016 -0.4747016]
#  [-0.5247016 -0.4247016]]
#
#
# Epoch 195 - Updated Weights:
#   Input to Hidden: [[0.1835719 0.2335719]
#  [0.2835719 0.3335719]]
#   Hidden to Output: [[-0.57472956 -0.47472956]
#  [-0.52472956 -0.42472956]]
#
#
# Epoch 196 - Updated Weights:
#   Input to Hidden: [[0.18374671 0.23374671]
#  [0.28374671 0.33374671]]
#   Hidden to Output: [[-0.57475634 -0.47475634]
#  [-0.52475634 -0.42475634]]
#
#
# Epoch 197 - Updated Weights:
#   Input to Hidden: [[0.18392149 0.23392149]
#  [0.28392149 0.33392149]]
#   Hidden to Output: [[-0.57478198 -0.47478198]
#  [-0.52478198 -0.42478198]]
#
#
# Epoch 198 - Updated Weights:
#   Input to Hidden: [[0.18409624 0.23409624]
#  [0.28409624 0.33409624]]
#   Hidden to Output: [[-0.57480653 -0.47480653]
#  [-0.52480653 -0.42480653]]
#
#
# Epoch 199 - Updated Weights:
#   Input to Hidden: [[0.18427095 0.23427095]
#  [0.28427095 0.33427095]]
#   Hidden to Output: [[-0.57483001 -0.47483001]
#  [-0.52483001 -0.42483001]]
#
#
# Epoch 200 - Updated Weights:
#   Input to Hidden: [[0.18444563 0.23444563]
#  [0.28444563 0.33444563]]
#   Hidden to Output: [[-0.57485247 -0.47485247]
#  [-0.52485247 -0.42485247]]
#
#
# Epoch 201 - Updated Weights:
#   Input to Hidden: [[0.18462028 0.23462028]
#  [0.28462028 0.33462028]]
#   Hidden to Output: [[-0.57487395 -0.47487395]
#  [-0.52487395 -0.42487395]]
#
#
# Epoch 202 - Updated Weights:
#   Input to Hidden: [[0.18479491 0.23479491]
#  [0.28479491 0.33479491]]
#   Hidden to Output: [[-0.57489448 -0.47489448]
#  [-0.52489448 -0.42489448]]
#
#
# Epoch 203 - Updated Weights:
#   Input to Hidden: [[0.1849695 0.2349695]
#  [0.2849695 0.3349695]]
#   Hidden to Output: [[-0.57491409 -0.47491409]
#  [-0.52491409 -0.42491409]]
#
#
# Epoch 204 - Updated Weights:
#   Input to Hidden: [[0.18514407 0.23514407]
#  [0.28514407 0.33514407]]
#   Hidden to Output: [[-0.57493282 -0.47493282]
#  [-0.52493282 -0.42493282]]
#
#
# Epoch 205 - Updated Weights:
#   Input to Hidden: [[0.18531861 0.23531861]
#  [0.28531861 0.33531861]]
#   Hidden to Output: [[-0.57495069 -0.47495069]
#  [-0.52495069 -0.42495069]]
#
#
# Epoch 206 - Updated Weights:
#   Input to Hidden: [[0.18549312 0.23549312]
#  [0.28549312 0.33549312]]
#   Hidden to Output: [[-0.57496774 -0.47496774]
#  [-0.52496774 -0.42496774]]
#
#
# Epoch 207 - Updated Weights:
#   Input to Hidden: [[0.18566762 0.23566762]
#  [0.28566762 0.33566762]]
#   Hidden to Output: [[-0.574984 -0.474984]
#  [-0.524984 -0.424984]]
#
#
# Epoch 208 - Updated Weights:
#   Input to Hidden: [[0.18584208 0.23584208]
#  [0.28584208 0.33584208]]
#   Hidden to Output: [[-0.5749995 -0.4749995]
#  [-0.5249995 -0.4249995]]
#
#
# Epoch 209 - Updated Weights:
#   Input to Hidden: [[0.18601653 0.23601653]
#  [0.28601653 0.33601653]]
#   Hidden to Output: [[-0.57501426 -0.47501426]
#  [-0.52501426 -0.42501426]]
#
#
# Epoch 210 - Updated Weights:
#   Input to Hidden: [[0.18619095 0.23619095]
#  [0.28619095 0.33619095]]
#   Hidden to Output: [[-0.5750283 -0.4750283]
#  [-0.5250283 -0.4250283]]
#
#
# Epoch 211 - Updated Weights:
#   Input to Hidden: [[0.18636535 0.23636535]
#  [0.28636535 0.33636535]]
#   Hidden to Output: [[-0.57504167 -0.47504167]
#  [-0.52504167 -0.42504167]]
#
#
# Epoch 212 - Updated Weights:
#   Input to Hidden: [[0.18653973 0.23653973]
#  [0.28653973 0.33653973]]
#   Hidden to Output: [[-0.57505437 -0.47505437]
#  [-0.52505437 -0.42505437]]
#
#
# Epoch 213 - Updated Weights:
#   Input to Hidden: [[0.18671409 0.23671409]
#  [0.28671409 0.33671409]]
#   Hidden to Output: [[-0.57506643 -0.47506643]
#  [-0.52506643 -0.42506643]]
#
#
# Epoch 214 - Updated Weights:
#   Input to Hidden: [[0.18688843 0.23688843]
#  [0.28688843 0.33688843]]
#   Hidden to Output: [[-0.57507787 -0.47507787]
#  [-0.52507787 -0.42507787]]
#
#
# Epoch 215 - Updated Weights:
#   Input to Hidden: [[0.18706276 0.23706276]
#  [0.28706276 0.33706276]]
#   Hidden to Output: [[-0.57508873 -0.47508873]
#  [-0.52508873 -0.42508873]]
#
#
# Epoch 216 - Updated Weights:
#   Input to Hidden: [[0.18723706 0.23723706]
#  [0.28723706 0.33723706]]
#   Hidden to Output: [[-0.57509901 -0.47509901]
#  [-0.52509901 -0.42509901]]
#
#
# Epoch 217 - Updated Weights:
#   Input to Hidden: [[0.18741135 0.23741135]
#  [0.28741135 0.33741135]]
#   Hidden to Output: [[-0.57510874 -0.47510874]
#  [-0.52510874 -0.42510874]]
#
#
# Epoch 218 - Updated Weights:
#   Input to Hidden: [[0.18758562 0.23758562]
#  [0.28758562 0.33758562]]
#   Hidden to Output: [[-0.57511793 -0.47511793]
#  [-0.52511793 -0.42511793]]
#
#
# Epoch 219 - Updated Weights:
#   Input to Hidden: [[0.18775988 0.23775988]
#  [0.28775988 0.33775988]]
#   Hidden to Output: [[-0.57512662 -0.47512662]
#  [-0.52512662 -0.42512662]]
#
#
# Epoch 220 - Updated Weights:
#   Input to Hidden: [[0.18793412 0.23793412]
#  [0.28793412 0.33793412]]
#   Hidden to Output: [[-0.57513481 -0.47513481]
#  [-0.52513481 -0.42513481]]
#
#
# Epoch 221 - Updated Weights:
#   Input to Hidden: [[0.18810834 0.23810834]
#  [0.28810834 0.33810834]]
#   Hidden to Output: [[-0.57514252 -0.47514252]
#  [-0.52514252 -0.42514252]]
#
#
# Epoch 222 - Updated Weights:
#   Input to Hidden: [[0.18828255 0.23828255]
#  [0.28828255 0.33828255]]
#   Hidden to Output: [[-0.57514977 -0.47514977]
#  [-0.52514977 -0.42514977]]
#
#
# Epoch 223 - Updated Weights:
#   Input to Hidden: [[0.18845674 0.23845674]
#  [0.28845674 0.33845674]]
#   Hidden to Output: [[-0.57515657 -0.47515657]
#  [-0.52515657 -0.42515657]]
#
#
# Epoch 224 - Updated Weights:
#   Input to Hidden: [[0.18863093 0.23863093]
#  [0.28863093 0.33863093]]
#   Hidden to Output: [[-0.57516295 -0.47516295]
#  [-0.52516295 -0.42516295]]
#
#
# Epoch 225 - Updated Weights:
#   Input to Hidden: [[0.18880509 0.23880509]
#  [0.28880509 0.33880509]]
#   Hidden to Output: [[-0.57516892 -0.47516892]
#  [-0.52516892 -0.42516892]]
#
#
# Epoch 226 - Updated Weights:
#   Input to Hidden: [[0.18897925 0.23897925]
#  [0.28897925 0.33897925]]
#   Hidden to Output: [[-0.57517448 -0.47517448]
#  [-0.52517448 -0.42517448]]
#
#
# Epoch 227 - Updated Weights:
#   Input to Hidden: [[0.18915339 0.23915339]
#  [0.28915339 0.33915339]]
#   Hidden to Output: [[-0.57517967 -0.47517967]
#  [-0.52517967 -0.42517967]]
#
#
# Epoch 228 - Updated Weights:
#   Input to Hidden: [[0.18932752 0.23932752]
#  [0.28932752 0.33932752]]
#   Hidden to Output: [[-0.57518448 -0.47518448]
#  [-0.52518448 -0.42518448]]
#
#
# Epoch 229 - Updated Weights:
#   Input to Hidden: [[0.18950164 0.23950164]
#  [0.28950164 0.33950164]]
#   Hidden to Output: [[-0.57518893 -0.47518893]
#  [-0.52518893 -0.42518893]]
#
#
# Epoch 230 - Updated Weights:
#   Input to Hidden: [[0.18967575 0.23967575]
#  [0.28967575 0.33967575]]
#   Hidden to Output: [[-0.57519304 -0.47519304]
#  [-0.52519304 -0.42519304]]
#
#
# Epoch 231 - Updated Weights:
#   Input to Hidden: [[0.18984985 0.23984985]
#  [0.28984985 0.33984985]]
#   Hidden to Output: [[-0.57519682 -0.47519682]
#  [-0.52519682 -0.42519682]]
#
#
# Epoch 232 - Updated Weights:
#   Input to Hidden: [[0.19002394 0.24002394]
#  [0.29002394 0.34002394]]
#   Hidden to Output: [[-0.57520028 -0.47520028]
#  [-0.52520028 -0.42520028]]
#
#
# Epoch 233 - Updated Weights:
#   Input to Hidden: [[0.19019801 0.24019801]
#  [0.29019801 0.34019801]]
#   Hidden to Output: [[-0.57520343 -0.47520343]
#  [-0.52520343 -0.42520343]]
#
#
# Epoch 234 - Updated Weights:
#   Input to Hidden: [[0.19037208 0.24037208]
#  [0.29037208 0.34037208]]
#   Hidden to Output: [[-0.57520628 -0.47520628]
#  [-0.52520628 -0.42520628]]
#
#
# Epoch 235 - Updated Weights:
#   Input to Hidden: [[0.19054614 0.24054614]
#  [0.29054614 0.34054614]]
#   Hidden to Output: [[-0.57520884 -0.47520884]
#  [-0.52520884 -0.42520884]]
#
#
# Epoch 236 - Updated Weights:
#   Input to Hidden: [[0.19072019 0.24072019]
#  [0.29072019 0.34072019]]
#   Hidden to Output: [[-0.57521113 -0.47521113]
#  [-0.52521113 -0.42521113]]
#
#
# Epoch 237 - Updated Weights:
#   Input to Hidden: [[0.19089423 0.24089423]
#  [0.29089423 0.34089423]]
#   Hidden to Output: [[-0.57521315 -0.47521315]
#  [-0.52521315 -0.42521315]]
#
#
# Epoch 238 - Updated Weights:
#   Input to Hidden: [[0.19106826 0.24106826]
#  [0.29106826 0.34106826]]
#   Hidden to Output: [[-0.57521491 -0.47521491]
#  [-0.52521491 -0.42521491]]
#
#
# Epoch 239 - Updated Weights:
#   Input to Hidden: [[0.19124228 0.24124228]
#  [0.29124228 0.34124228]]
#   Hidden to Output: [[-0.57521642 -0.47521642]
#  [-0.52521642 -0.42521642]]
#
#
# Epoch 240 - Updated Weights:
#   Input to Hidden: [[0.19141629 0.24141629]
#  [0.29141629 0.34141629]]
#   Hidden to Output: [[-0.57521769 -0.47521769]
#  [-0.52521769 -0.42521769]]
#
#
# Epoch 241 - Updated Weights:
#   Input to Hidden: [[0.1915903 0.2415903]
#  [0.2915903 0.3415903]]
#   Hidden to Output: [[-0.57521873 -0.47521873]
#  [-0.52521873 -0.42521873]]
#
#
# Epoch 242 - Updated Weights:
#   Input to Hidden: [[0.1917643 0.2417643]
#  [0.2917643 0.3417643]]
#   Hidden to Output: [[-0.57521955 -0.47521955]
#  [-0.52521955 -0.42521955]]
#
#
# Epoch 243 - Updated Weights:
#   Input to Hidden: [[0.19193829 0.24193829]
#  [0.29193829 0.34193829]]
#   Hidden to Output: [[-0.57522015 -0.47522015]
#  [-0.52522015 -0.42522015]]
#
#
# Epoch 244 - Updated Weights:
#   Input to Hidden: [[0.19211228 0.24211228]
#  [0.29211228 0.34211228]]
#   Hidden to Output: [[-0.57522055 -0.47522055]
#  [-0.52522055 -0.42522055]]
#
#
# Epoch 245 - Updated Weights:
#   Input to Hidden: [[0.19228625 0.24228625]
#  [0.29228625 0.34228625]]
#   Hidden to Output: [[-0.57522074 -0.47522074]
#  [-0.52522074 -0.42522074]]
#
#
# Epoch 246 - Updated Weights:
#   Input to Hidden: [[0.19246022 0.24246022]
#  [0.29246022 0.34246022]]
#   Hidden to Output: [[-0.57522075 -0.47522075]
#  [-0.52522075 -0.42522075]]
#
#
# Epoch 247 - Updated Weights:
#   Input to Hidden: [[0.19263419 0.24263419]
#  [0.29263419 0.34263419]]
#   Hidden to Output: [[-0.57522056 -0.47522056]
#  [-0.52522056 -0.42522056]]
#
#
# Epoch 248 - Updated Weights:
#   Input to Hidden: [[0.19280815 0.24280815]
#  [0.29280815 0.34280815]]
#   Hidden to Output: [[-0.5752202 -0.4752202]
#  [-0.5252202 -0.4252202]]
#
#
# Epoch 249 - Updated Weights:
#   Input to Hidden: [[0.1929821 0.2429821]
#  [0.2929821 0.3429821]]
#   Hidden to Output: [[-0.57521966 -0.47521966]
#  [-0.52521966 -0.42521966]]
#
#
# Epoch 250 - Updated Weights:
#   Input to Hidden: [[0.19315604 0.24315604]
#  [0.29315604 0.34315604]]
#   Hidden to Output: [[-0.57521896 -0.47521896]
#  [-0.52521896 -0.42521896]]
#
#
# Epoch 251 - Updated Weights:
#   Input to Hidden: [[0.19332998 0.24332998]
#  [0.29332998 0.34332998]]
#   Hidden to Output: [[-0.5752181 -0.4752181]
#  [-0.5252181 -0.4252181]]
#
#
# Epoch 252 - Updated Weights:
#   Input to Hidden: [[0.19350392 0.24350392]
#  [0.29350392 0.34350392]]
#   Hidden to Output: [[-0.57521708 -0.47521708]
#  [-0.52521708 -0.42521708]]
#
#
# Epoch 253 - Updated Weights:
#   Input to Hidden: [[0.19367785 0.24367785]
#  [0.29367785 0.34367785]]
#   Hidden to Output: [[-0.57521591 -0.47521591]
#  [-0.52521591 -0.42521591]]
#
#
# Epoch 254 - Updated Weights:
#   Input to Hidden: [[0.19385177 0.24385177]
#  [0.29385177 0.34385177]]
#   Hidden to Output: [[-0.5752146 -0.4752146]
#  [-0.5252146 -0.4252146]]
#
#
# Epoch 255 - Updated Weights:
#   Input to Hidden: [[0.19402569 0.24402569]
#  [0.29402569 0.34402569]]
#   Hidden to Output: [[-0.57521314 -0.47521314]
#  [-0.52521314 -0.42521314]]
#
#
# Epoch 256 - Updated Weights:
#   Input to Hidden: [[0.1941996 0.2441996]
#  [0.2941996 0.3441996]]
#   Hidden to Output: [[-0.57521156 -0.47521156]
#  [-0.52521156 -0.42521156]]
#
#
# Epoch 257 - Updated Weights:
#   Input to Hidden: [[0.19437351 0.24437351]
#  [0.29437351 0.34437351]]
#   Hidden to Output: [[-0.57520984 -0.47520984]
#  [-0.52520984 -0.42520984]]
#
#
# Epoch 258 - Updated Weights:
#   Input to Hidden: [[0.19454742 0.24454742]
#  [0.29454742 0.34454742]]
#   Hidden to Output: [[-0.575208 -0.475208]
#  [-0.525208 -0.425208]]
#
#
# Epoch 259 - Updated Weights:
#   Input to Hidden: [[0.19472132 0.24472132]
#  [0.29472132 0.34472132]]
#   Hidden to Output: [[-0.57520604 -0.47520604]
#  [-0.52520604 -0.42520604]]
#
#
# Epoch 260 - Updated Weights:
#   Input to Hidden: [[0.19489521 0.24489521]
#  [0.29489521 0.34489521]]
#   Hidden to Output: [[-0.57520396 -0.47520396]
#  [-0.52520396 -0.42520396]]
#
#
# Epoch 261 - Updated Weights:
#   Input to Hidden: [[0.1950691 0.2450691]
#  [0.2950691 0.3450691]]
#   Hidden to Output: [[-0.57520177 -0.47520177]
#  [-0.52520177 -0.42520177]]
#
#
# Epoch 262 - Updated Weights:
#   Input to Hidden: [[0.19524299 0.24524299]
#  [0.29524299 0.34524299]]
#   Hidden to Output: [[-0.57519948 -0.47519948]
#  [-0.52519948 -0.42519948]]
#
#
# Epoch 263 - Updated Weights:
#   Input to Hidden: [[0.19541687 0.24541687]
#  [0.29541687 0.34541687]]
#   Hidden to Output: [[-0.57519708 -0.47519708]
#  [-0.52519708 -0.42519708]]
#
#
# Epoch 264 - Updated Weights:
#   Input to Hidden: [[0.19559075 0.24559075]
#  [0.29559075 0.34559075]]
#   Hidden to Output: [[-0.57519457 -0.47519457]
#  [-0.52519457 -0.42519457]]
#
#
# Epoch 265 - Updated Weights:
#   Input to Hidden: [[0.19576462 0.24576462]
#  [0.29576462 0.34576462]]
#   Hidden to Output: [[-0.57519198 -0.47519198]
#  [-0.52519198 -0.42519198]]
#
#
# Epoch 266 - Updated Weights:
#   Input to Hidden: [[0.1959385 0.2459385]
#  [0.2959385 0.3459385]]
#   Hidden to Output: [[-0.57518928 -0.47518928]
#  [-0.52518928 -0.42518928]]
#
#
# Epoch 267 - Updated Weights:
#   Input to Hidden: [[0.19611236 0.24611236]
#  [0.29611236 0.34611236]]
#   Hidden to Output: [[-0.5751865 -0.4751865]
#  [-0.5251865 -0.4251865]]
#
#
# Epoch 268 - Updated Weights:
#   Input to Hidden: [[0.19628623 0.24628623]
#  [0.29628623 0.34628623]]
#   Hidden to Output: [[-0.57518363 -0.47518363]
#  [-0.52518363 -0.42518363]]
#
#
# Epoch 269 - Updated Weights:
#   Input to Hidden: [[0.19646009 0.24646009]
#  [0.29646009 0.34646009]]
#   Hidden to Output: [[-0.57518068 -0.47518068]
#  [-0.52518068 -0.42518068]]
#
#
# Epoch 270 - Updated Weights:
#   Input to Hidden: [[0.19663394 0.24663394]
#  [0.29663394 0.34663394]]
#   Hidden to Output: [[-0.57517765 -0.47517765]
#  [-0.52517765 -0.42517765]]
#
#
# Epoch 271 - Updated Weights:
#   Input to Hidden: [[0.1968078 0.2468078]
#  [0.2968078 0.3468078]]
#   Hidden to Output: [[-0.57517454 -0.47517454]
#  [-0.52517454 -0.42517454]]
#
#
# Epoch 272 - Updated Weights:
#   Input to Hidden: [[0.19698165 0.24698165]
#  [0.29698165 0.34698165]]
#   Hidden to Output: [[-0.57517135 -0.47517135]
#  [-0.52517135 -0.42517135]]
#
#
# Epoch 273 - Updated Weights:
#   Input to Hidden: [[0.19715549 0.24715549]
#  [0.29715549 0.34715549]]
#   Hidden to Output: [[-0.57516809 -0.47516809]
#  [-0.52516809 -0.42516809]]
#
#
# Epoch 274 - Updated Weights:
#   Input to Hidden: [[0.19732934 0.24732934]
#  [0.29732934 0.34732934]]
#   Hidden to Output: [[-0.57516477 -0.47516477]
#  [-0.52516477 -0.42516477]]
#
#
# Epoch 275 - Updated Weights:
#   Input to Hidden: [[0.19750318 0.24750318]
#  [0.29750318 0.34750318]]
#   Hidden to Output: [[-0.57516137 -0.47516137]
#  [-0.52516137 -0.42516137]]
#
#
# ...
#  [-0.52193335 -0.42193335]]
#
#
# Epoch 910 - Updated Weights:
#   Input to Hidden: [[0.30765596 0.35765596]
#  [0.40765596 0.45765596]]
#   Hidden to Output: [[-0.57192823 -0.47192823]
#  [-0.52192823 -0.42192823]]
#
#
# Epoch 911 - Updated Weights:
#   Input to Hidden: [[0.3078291 0.3578291]
#  [0.4078291 0.4578291]]
#   Hidden to Output: [[-0.57192312 -0.47192312]
#  [-0.52192312 -0.42192312]]
#
#
# Epoch 912 - Updated Weights:
#   Input to Hidden: [[0.30800225 0.35800225]
#  [0.40800225 0.45800225]]
#   Hidden to Output: [[-0.571918 -0.471918]
#  [-0.521918 -0.421918]]
#
#
# Epoch 913 - Updated Weights:
#   Input to Hidden: [[0.30817539 0.35817539]
#  [0.40817539 0.45817539]]
#   Hidden to Output: [[-0.57191288 -0.47191288]
#  [-0.52191288 -0.42191288]]
#
#
# Epoch 914 - Updated Weights:
#   Input to Hidden: [[0.30834853 0.35834853]
#  [0.40834853 0.45834853]]
#   Hidden to Output: [[-0.57190777 -0.47190777]
#  [-0.52190777 -0.42190777]]
#
#
# Epoch 915 - Updated Weights:
#   Input to Hidden: [[0.30852167 0.35852167]
#  [0.40852167 0.45852167]]
#   Hidden to Output: [[-0.57190265 -0.47190265]
#  [-0.52190265 -0.42190265]]
#
#
# Epoch 916 - Updated Weights:
#   Input to Hidden: [[0.3086948 0.3586948]
#  [0.4086948 0.4586948]]
#   Hidden to Output: [[-0.57189753 -0.47189753]
#  [-0.52189753 -0.42189753]]
#
#
# Epoch 917 - Updated Weights:
#   Input to Hidden: [[0.30886794 0.35886794]
#  [0.40886794 0.45886794]]
#   Hidden to Output: [[-0.57189242 -0.47189242]
#  [-0.52189242 -0.42189242]]
#
#
# Epoch 918 - Updated Weights:
#   Input to Hidden: [[0.30904108 0.35904108]
#  [0.40904108 0.45904108]]
#   Hidden to Output: [[-0.5718873 -0.4718873]
#  [-0.5218873 -0.4218873]]
#
#
# Epoch 919 - Updated Weights:
#   Input to Hidden: [[0.30921421 0.35921421]
#  [0.40921421 0.45921421]]
#   Hidden to Output: [[-0.57188219 -0.47188219]
#  [-0.52188219 -0.42188219]]
#
#
# Epoch 920 - Updated Weights:
#   Input to Hidden: [[0.30938735 0.35938735]
#  [0.40938735 0.45938735]]
#   Hidden to Output: [[-0.57187707 -0.47187707]
#  [-0.52187707 -0.42187707]]
#
#
# Epoch 921 - Updated Weights:
#   Input to Hidden: [[0.30956048 0.35956048]
#  [0.40956048 0.45956048]]
#   Hidden to Output: [[-0.57187195 -0.47187195]
#  [-0.52187195 -0.42187195]]
#
#
# Epoch 922 - Updated Weights:
#   Input to Hidden: [[0.30973361 0.35973361]
#  [0.40973361 0.45973361]]
#   Hidden to Output: [[-0.57186684 -0.47186684]
#  [-0.52186684 -0.42186684]]
#
#
# Epoch 923 - Updated Weights:
#   Input to Hidden: [[0.30990674 0.35990674]
#  [0.40990674 0.45990674]]
#   Hidden to Output: [[-0.57186172 -0.47186172]
#  [-0.52186172 -0.42186172]]
#
#
# Epoch 924 - Updated Weights:
#   Input to Hidden: [[0.31007987 0.36007987]
#  [0.41007987 0.46007987]]
#   Hidden to Output: [[-0.57185661 -0.47185661]
#  [-0.52185661 -0.42185661]]
#
#
# Epoch 925 - Updated Weights:
#   Input to Hidden: [[0.310253 0.360253]
#  [0.410253 0.460253]]
#   Hidden to Output: [[-0.57185149 -0.47185149]
#  [-0.52185149 -0.42185149]]
#
#
# Epoch 926 - Updated Weights:
#   Input to Hidden: [[0.31042613 0.36042613]
#  [0.41042613 0.46042613]]
#   Hidden to Output: [[-0.57184638 -0.47184638]
#  [-0.52184638 -0.42184638]]
#
#
# Epoch 927 - Updated Weights:
#   Input to Hidden: [[0.31059926 0.36059926]
#  [0.41059926 0.46059926]]
#   Hidden to Output: [[-0.57184127 -0.47184127]
#  [-0.52184127 -0.42184127]]
#
#
# Epoch 928 - Updated Weights:
#   Input to Hidden: [[0.31077238 0.36077238]
#  [0.41077238 0.46077238]]
#   Hidden to Output: [[-0.57183615 -0.47183615]
#  [-0.52183615 -0.42183615]]
#
#
# Epoch 929 - Updated Weights:
#   Input to Hidden: [[0.31094551 0.36094551]
#  [0.41094551 0.46094551]]
#   Hidden to Output: [[-0.57183104 -0.47183104]
#  [-0.52183104 -0.42183104]]
#
#
# Epoch 930 - Updated Weights:
#   Input to Hidden: [[0.31111863 0.36111863]
#  [0.41111863 0.46111863]]
#   Hidden to Output: [[-0.57182592 -0.47182592]
#  [-0.52182592 -0.42182592]]
#
#
# Epoch 931 - Updated Weights:
#   Input to Hidden: [[0.31129176 0.36129176]
#  [0.41129176 0.46129176]]
#   Hidden to Output: [[-0.57182081 -0.47182081]
#  [-0.52182081 -0.42182081]]
#
#
# Epoch 932 - Updated Weights:
#   Input to Hidden: [[0.31146488 0.36146488]
#  [0.41146488 0.46146488]]
#   Hidden to Output: [[-0.5718157 -0.4718157]
#  [-0.5218157 -0.4218157]]
#
#
# Epoch 933 - Updated Weights:
#   Input to Hidden: [[0.311638 0.361638]
#  [0.411638 0.461638]]
#   Hidden to Output: [[-0.57181058 -0.47181058]
#  [-0.52181058 -0.42181058]]
#
#
# Epoch 934 - Updated Weights:
#   Input to Hidden: [[0.31181112 0.36181112]
#  [0.41181112 0.46181112]]
#   Hidden to Output: [[-0.57180547 -0.47180547]
#  [-0.52180547 -0.42180547]]
#
#
# Epoch 935 - Updated Weights:
#   Input to Hidden: [[0.31198424 0.36198424]
#  [0.41198424 0.46198424]]
#   Hidden to Output: [[-0.57180036 -0.47180036]
#  [-0.52180036 -0.42180036]]
#
#
# Epoch 936 - Updated Weights:
#   Input to Hidden: [[0.31215735 0.36215735]
#  [0.41215735 0.46215735]]
#   Hidden to Output: [[-0.57179524 -0.47179524]
#  [-0.52179524 -0.42179524]]
#
#
# Epoch 937 - Updated Weights:
#   Input to Hidden: [[0.31233047 0.36233047]
#  [0.41233047 0.46233047]]
#   Hidden to Output: [[-0.57179013 -0.47179013]
#  [-0.52179013 -0.42179013]]
#
#
# Epoch 938 - Updated Weights:
#   Input to Hidden: [[0.31250359 0.36250359]
#  [0.41250359 0.46250359]]
#   Hidden to Output: [[-0.57178502 -0.47178502]
#  [-0.52178502 -0.42178502]]
#
#
# Epoch 939 - Updated Weights:
#   Input to Hidden: [[0.3126767 0.3626767]
#  [0.4126767 0.4626767]]
#   Hidden to Output: [[-0.5717799 -0.4717799]
#  [-0.5217799 -0.4217799]]
#
#
# Epoch 940 - Updated Weights:
#   Input to Hidden: [[0.31284981 0.36284981]
#  [0.41284981 0.46284981]]
#   Hidden to Output: [[-0.57177479 -0.47177479]
#  [-0.52177479 -0.42177479]]
#
#
# Epoch 941 - Updated Weights:
#   Input to Hidden: [[0.31302293 0.36302293]
#  [0.41302293 0.46302293]]
#   Hidden to Output: [[-0.57176968 -0.47176968]
#  [-0.52176968 -0.42176968]]
#
#
# Epoch 942 - Updated Weights:
#   Input to Hidden: [[0.31319604 0.36319604]
#  [0.41319604 0.46319604]]
#   Hidden to Output: [[-0.57176457 -0.47176457]
#  [-0.52176457 -0.42176457]]
#
#
# Epoch 943 - Updated Weights:
#   Input to Hidden: [[0.31336915 0.36336915]
#  [0.41336915 0.46336915]]
#   Hidden to Output: [[-0.57175946 -0.47175946]
#  [-0.52175946 -0.42175946]]
#
#
# Epoch 944 - Updated Weights:
#   Input to Hidden: [[0.31354226 0.36354226]
#  [0.41354226 0.46354226]]
#   Hidden to Output: [[-0.57175434 -0.47175434]
#  [-0.52175434 -0.42175434]]
#
#
# Epoch 945 - Updated Weights:
#   Input to Hidden: [[0.31371537 0.36371537]
#  [0.41371537 0.46371537]]
#   Hidden to Output: [[-0.57174923 -0.47174923]
#  [-0.52174923 -0.42174923]]
#
#
# Epoch 946 - Updated Weights:
#   Input to Hidden: [[0.31388847 0.36388847]
#  [0.41388847 0.46388847]]
#   Hidden to Output: [[-0.57174412 -0.47174412]
#  [-0.52174412 -0.42174412]]
#
#
# Epoch 947 - Updated Weights:
#   Input to Hidden: [[0.31406158 0.36406158]
#  [0.41406158 0.46406158]]
#   Hidden to Output: [[-0.57173901 -0.47173901]
#  [-0.52173901 -0.42173901]]
#
#
# Epoch 948 - Updated Weights:
#   Input to Hidden: [[0.31423469 0.36423469]
#  [0.41423469 0.46423469]]
#   Hidden to Output: [[-0.5717339 -0.4717339]
#  [-0.5217339 -0.4217339]]
#
#
# Epoch 949 - Updated Weights:
#   Input to Hidden: [[0.31440779 0.36440779]
#  [0.41440779 0.46440779]]
#   Hidden to Output: [[-0.57172879 -0.47172879]
#  [-0.52172879 -0.42172879]]
#
#
# Epoch 950 - Updated Weights:
#   Input to Hidden: [[0.31458089 0.36458089]
#  [0.41458089 0.46458089]]
#   Hidden to Output: [[-0.57172368 -0.47172368]
#  [-0.52172368 -0.42172368]]
#
#
# Epoch 951 - Updated Weights:
#   Input to Hidden: [[0.314754 0.364754]
#  [0.414754 0.464754]]
#   Hidden to Output: [[-0.57171857 -0.47171857]
#  [-0.52171857 -0.42171857]]
#
#
# Epoch 952 - Updated Weights:
#   Input to Hidden: [[0.3149271 0.3649271]
#  [0.4149271 0.4649271]]
#   Hidden to Output: [[-0.57171346 -0.47171346]
#  [-0.52171346 -0.42171346]]
#
#
# Epoch 953 - Updated Weights:
#   Input to Hidden: [[0.3151002 0.3651002]
#  [0.4151002 0.4651002]]
#   Hidden to Output: [[-0.57170835 -0.47170835]
#  [-0.52170835 -0.42170835]]
#
#
# Epoch 954 - Updated Weights:
#   Input to Hidden: [[0.3152733 0.3652733]
#  [0.4152733 0.4652733]]
#   Hidden to Output: [[-0.57170324 -0.47170324]
#  [-0.52170324 -0.42170324]]
#
#
# Epoch 955 - Updated Weights:
#   Input to Hidden: [[0.3154464 0.3654464]
#  [0.4154464 0.4654464]]
#   Hidden to Output: [[-0.57169813 -0.47169813]
#  [-0.52169813 -0.42169813]]
#
#
# Epoch 956 - Updated Weights:
#   Input to Hidden: [[0.31561949 0.36561949]
#  [0.41561949 0.46561949]]
#   Hidden to Output: [[-0.57169302 -0.47169302]
#  [-0.52169302 -0.42169302]]
#
#
# Epoch 957 - Updated Weights:
#   Input to Hidden: [[0.31579259 0.36579259]
#  [0.41579259 0.46579259]]
#   Hidden to Output: [[-0.57168791 -0.47168791]
#  [-0.52168791 -0.42168791]]
#
#
# Epoch 958 - Updated Weights:
#   Input to Hidden: [[0.31596568 0.36596568]
#  [0.41596568 0.46596568]]
#   Hidden to Output: [[-0.5716828 -0.4716828]
#  [-0.5216828 -0.4216828]]
#
#
# Epoch 959 - Updated Weights:
#   Input to Hidden: [[0.31613878 0.36613878]
#  [0.41613878 0.46613878]]
#   Hidden to Output: [[-0.57167769 -0.47167769]
#  [-0.52167769 -0.42167769]]
#
#
# Epoch 960 - Updated Weights:
#   Input to Hidden: [[0.31631187 0.36631187]
#  [0.41631187 0.46631187]]
#   Hidden to Output: [[-0.57167258 -0.47167258]
#  [-0.52167258 -0.42167258]]
#
#
# Epoch 961 - Updated Weights:
#   Input to Hidden: [[0.31648496 0.36648496]
#  [0.41648496 0.46648496]]
#   Hidden to Output: [[-0.57166747 -0.47166747]
#  [-0.52166747 -0.42166747]]
#
#
# Epoch 962 - Updated Weights:
#   Input to Hidden: [[0.31665805 0.36665805]
#  [0.41665805 0.46665805]]
#   Hidden to Output: [[-0.57166236 -0.47166236]
#  [-0.52166236 -0.42166236]]
#
#
# Epoch 963 - Updated Weights:
#   Input to Hidden: [[0.31683114 0.36683114]
#  [0.41683114 0.46683114]]
#   Hidden to Output: [[-0.57165725 -0.47165725]
#  [-0.52165725 -0.42165725]]
#
#
# Epoch 964 - Updated Weights:
#   Input to Hidden: [[0.31700423 0.36700423]
#  [0.41700423 0.46700423]]
#   Hidden to Output: [[-0.57165214 -0.47165214]
#  [-0.52165214 -0.42165214]]
#
#
# Epoch 965 - Updated Weights:
#   Input to Hidden: [[0.31717732 0.36717732]
#  [0.41717732 0.46717732]]
#   Hidden to Output: [[-0.57164704 -0.47164704]
#  [-0.52164704 -0.42164704]]
#
#
# Epoch 966 - Updated Weights:
#   Input to Hidden: [[0.31735041 0.36735041]
#  [0.41735041 0.46735041]]
#   Hidden to Output: [[-0.57164193 -0.47164193]
#  [-0.52164193 -0.42164193]]
#
#
# Epoch 967 - Updated Weights:
#   Input to Hidden: [[0.31752349 0.36752349]
#  [0.41752349 0.46752349]]
#   Hidden to Output: [[-0.57163682 -0.47163682]
#  [-0.52163682 -0.42163682]]
#
#
# Epoch 968 - Updated Weights:
#   Input to Hidden: [[0.31769658 0.36769658]
#  [0.41769658 0.46769658]]
#   Hidden to Output: [[-0.57163171 -0.47163171]
#  [-0.52163171 -0.42163171]]
#
#
# Epoch 969 - Updated Weights:
#   Input to Hidden: [[0.31786966 0.36786966]
#  [0.41786966 0.46786966]]
#   Hidden to Output: [[-0.5716266 -0.4716266]
#  [-0.5216266 -0.4216266]]
#
#
# Epoch 970 - Updated Weights:
#   Input to Hidden: [[0.31804275 0.36804275]
#  [0.41804275 0.46804275]]
#   Hidden to Output: [[-0.5716215 -0.4716215]
#  [-0.5216215 -0.4216215]]
#
#
# Epoch 971 - Updated Weights:
#   Input to Hidden: [[0.31821583 0.36821583]
#  [0.41821583 0.46821583]]
#   Hidden to Output: [[-0.57161639 -0.47161639]
#  [-0.52161639 -0.42161639]]
#
#
# Epoch 972 - Updated Weights:
#   Input to Hidden: [[0.31838891 0.36838891]
#  [0.41838891 0.46838891]]
#   Hidden to Output: [[-0.57161128 -0.47161128]
#  [-0.52161128 -0.42161128]]
#
#
# Epoch 973 - Updated Weights:
#   Input to Hidden: [[0.31856199 0.36856199]
#  [0.41856199 0.46856199]]
#   Hidden to Output: [[-0.57160618 -0.47160618]
#  [-0.52160618 -0.42160618]]
#
#
# Epoch 974 - Updated Weights:
#   Input to Hidden: [[0.31873507 0.36873507]
#  [0.41873507 0.46873507]]
#   Hidden to Output: [[-0.57160107 -0.47160107]
#  [-0.52160107 -0.42160107]]
#
#
# Epoch 975 - Updated Weights:
#   Input to Hidden: [[0.31890814 0.36890814]
#  [0.41890814 0.46890814]]
#   Hidden to Output: [[-0.57159596 -0.47159596]
#  [-0.52159596 -0.42159596]]
#
#
# Epoch 976 - Updated Weights:
#   Input to Hidden: [[0.31908122 0.36908122]
#  [0.41908122 0.46908122]]
#   Hidden to Output: [[-0.57159086 -0.47159086]
#  [-0.52159086 -0.42159086]]
#
#
# Epoch 977 - Updated Weights:
#   Input to Hidden: [[0.3192543 0.3692543]
#  [0.4192543 0.4692543]]
#   Hidden to Output: [[-0.57158575 -0.47158575]
#  [-0.52158575 -0.42158575]]
#
#
# Epoch 978 - Updated Weights:
#   Input to Hidden: [[0.31942737 0.36942737]
#  [0.41942737 0.46942737]]
#   Hidden to Output: [[-0.57158064 -0.47158064]
#  [-0.52158064 -0.42158064]]
#
#
# Epoch 979 - Updated Weights:
#   Input to Hidden: [[0.31960044 0.36960044]
#  [0.41960044 0.46960044]]
#   Hidden to Output: [[-0.57157554 -0.47157554]
#  [-0.52157554 -0.42157554]]
#
#
# Epoch 980 - Updated Weights:
#   Input to Hidden: [[0.31977352 0.36977352]
#  [0.41977352 0.46977352]]
#   Hidden to Output: [[-0.57157043 -0.47157043]
#  [-0.52157043 -0.42157043]]
#
#
# Epoch 981 - Updated Weights:
#   Input to Hidden: [[0.31994659 0.36994659]
#  [0.41994659 0.46994659]]
#   Hidden to Output: [[-0.57156533 -0.47156533]
#  [-0.52156533 -0.42156533]]
#
#
# Epoch 982 - Updated Weights:
#   Input to Hidden: [[0.32011966 0.37011966]
#  [0.42011966 0.47011966]]
#   Hidden to Output: [[-0.57156022 -0.47156022]
#  [-0.52156022 -0.42156022]]
#
#
# Epoch 983 - Updated Weights:
#   Input to Hidden: [[0.32029273 0.37029273]
#  [0.42029273 0.47029273]]
#   Hidden to Output: [[-0.57155511 -0.47155511]
#  [-0.52155511 -0.42155511]]
#
#
# Epoch 984 - Updated Weights:
#   Input to Hidden: [[0.3204658 0.3704658]
#  [0.4204658 0.4704658]]
#   Hidden to Output: [[-0.57155001 -0.47155001]
#  [-0.52155001 -0.42155001]]
#
#
# Epoch 985 - Updated Weights:
#   Input to Hidden: [[0.32063886 0.37063886]
#  [0.42063886 0.47063886]]
#   Hidden to Output: [[-0.5715449 -0.4715449]
#  [-0.5215449 -0.4215449]]
#
#
# Epoch 986 - Updated Weights:
#   Input to Hidden: [[0.32081193 0.37081193]
#  [0.42081193 0.47081193]]
#   Hidden to Output: [[-0.5715398 -0.4715398]
#  [-0.5215398 -0.4215398]]
#
#
# Epoch 987 - Updated Weights:
#   Input to Hidden: [[0.320985 0.370985]
#  [0.420985 0.470985]]
#   Hidden to Output: [[-0.57153469 -0.47153469]
#  [-0.52153469 -0.42153469]]
#
#
# Epoch 988 - Updated Weights:
#   Input to Hidden: [[0.32115806 0.37115806]
#  [0.42115806 0.47115806]]
#   Hidden to Output: [[-0.57152959 -0.47152959]
#  [-0.52152959 -0.42152959]]
#
#
# Epoch 989 - Updated Weights:
#   Input to Hidden: [[0.32133112 0.37133112]
#  [0.42133112 0.47133112]]
#   Hidden to Output: [[-0.57152449 -0.47152449]
#  [-0.52152449 -0.42152449]]
#
#
# Epoch 990 - Updated Weights:
#   Input to Hidden: [[0.32150419 0.37150419]
#  [0.42150419 0.47150419]]
#   Hidden to Output: [[-0.57151938 -0.47151938]
#  [-0.52151938 -0.42151938]]
#
#
# Epoch 991 - Updated Weights:
#   Input to Hidden: [[0.32167725 0.37167725]
#  [0.42167725 0.47167725]]
#   Hidden to Output: [[-0.57151428 -0.47151428]
#  [-0.52151428 -0.42151428]]
#
#
# Epoch 992 - Updated Weights:
#   Input to Hidden: [[0.32185031 0.37185031]
#  [0.42185031 0.47185031]]
#   Hidden to Output: [[-0.57150917 -0.47150917]
#  [-0.52150917 -0.42150917]]
#
#
# Epoch 993 - Updated Weights:
#   Input to Hidden: [[0.32202337 0.37202337]
#  [0.42202337 0.47202337]]
#   Hidden to Output: [[-0.57150407 -0.47150407]
#  [-0.52150407 -0.42150407]]
#
#
# Epoch 994 - Updated Weights:
#   Input to Hidden: [[0.32219642 0.37219642]
#  [0.42219642 0.47219642]]
#   Hidden to Output: [[-0.57149897 -0.47149897]
#  [-0.52149897 -0.42149897]]
#
#
# Epoch 995 - Updated Weights:
#   Input to Hidden: [[0.32236948 0.37236948]
#  [0.42236948 0.47236948]]
#   Hidden to Output: [[-0.57149386 -0.47149386]
#  [-0.52149386 -0.42149386]]
#
#
# Epoch 996 - Updated Weights:
#   Input to Hidden: [[0.32254254 0.37254254]
#  [0.42254254 0.47254254]]
#   Hidden to Output: [[-0.57148876 -0.47148876]
#  [-0.52148876 -0.42148876]]
#
#
# Epoch 997 - Updated Weights:
#   Input to Hidden: [[0.32271559 0.37271559]
#  [0.42271559 0.47271559]]
#   Hidden to Output: [[-0.57148366 -0.47148366]
#  [-0.52148366 -0.42148366]]
#
#
# Epoch 998 - Updated Weights:
#   Input to Hidden: [[0.32288865 0.37288865]
#  [0.42288865 0.47288865]]
#   Hidden to Output: [[-0.57147855 -0.47147855]
#  [-0.52147855 -0.42147855]]
#
#
# Epoch 999 - Updated Weights:
#   Input to Hidden: [[0.3230617 0.3730617]
#  [0.4230617 0.4730617]]
#   Hidden to Output: [[-0.57147345 -0.47147345]
#  [-0.52147345 -0.42147345]]
#
#
# Epoch 1000 - Updated Weights:
#   Input to Hidden: [[0.32323475 0.37323475]
#  [0.42323475 0.47323475]]
#   Hidden to Output: [[-0.57146835 -0.47146835]
#  [-0.52146835 -0.42146835]]
#
#
# Predicted output: [[0.48563113 0.51570317]]
